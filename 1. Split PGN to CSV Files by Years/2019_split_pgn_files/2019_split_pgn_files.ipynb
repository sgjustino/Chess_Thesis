# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/thesis-chess-dataset/fourthSorted.pgn

# %%
import os

# Splits the PGN file into parts, each containing up to 'split_size' games from a specific year, and saves them to the output folder
def split_and_filter_games_by_year(pgn_file_path, year, split_size, output_folder):
    
    os.makedirs(output_folder, exist_ok=True)
    
    current_file_number = 1
    game_count = 0
    current_file_path = os.path.join(output_folder, f"games_2019_part_{current_file_number}.pgn")
    current_file = open(current_file_path, "w")
    
    with open(pgn_file_path, "r") as pgn:
        game_lines = []  # Hold the lines of a game
        for line in pgn:
            if line.startswith('[Event '):
                # Process the previous game
                if game_lines:
                    date_line = next((l for l in game_lines if l.startswith('[Date ')), '')
                    game_year = date_line.split('"')[1].split('.')[0]  # Extract the year part
                    if game_year == year:
                        game_count += 1
                        if game_count > split_size:
                            # Close current file and open a new one
                            current_file.close()
                            current_file_number += 1
                            current_file_path = os.path.join(output_folder, f"games_2019_part_{current_file_number}.pgn")
                            current_file = open(current_file_path, "w")
                            game_count = 1  # Reset the count for the new file
                        current_file.writelines(game_lines)
                game_lines = [line]  # Start a new game
            else:
                game_lines.append(line)
        
        # Check for the last game in the file
        if game_lines:
            date_line = next((l for l in game_lines if l.startswith('[Date ')), '')
            game_year = date_line.split('"')[1].split('.')[0]
            if game_year == year:
                current_file.writelines(game_lines)
                
    current_file.close()  # Ensure the last file is closed after the loop finishes

# Path to the directory containing the PGN file
pgn_file_path = "/kaggle/input/thesis-chess-dataset/fourthSorted.pgn"
# Selection of filter for year
year = "2019"
# File size for split by no. of games
split_size = 10000

output_folder = "pgn_2019_data"

# Call the function
split_and_filter_games_by_year(pgn_file_path, year, split_size, output_folder)

# %%
pip install converter pgn2data
# Out:
# Collecting converter
#   Downloading converter-1.0.0.zip (1.3 kB)
# done
# Collecting pgn2data
#   Downloading pgn2data-0.0.9-py3-none-any.whl.metadata (9.8 kB)
# Collecting chess (from pgn2data)
#   Downloading chess-1.10.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from pgn2data) (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->pgn2data) (1.16.0)
# Downloading pgn2data-0.0.9-py3-none-any.whl (31 kB)
# Downloading chess-1.10.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.3 MB/s eta 0:00:00
# Building wheels for collected packages: converter
# done
#   Created wheel for converter: filename=converter-1.0.0-py3-none-any.whl size=1751 sha256=89a0128a330e306004f8f27782bbdfab3881c2285d7e06465a17f103a9706704
#   Stored in directory: /root/.cache/pip/wheels/fd/74/44/8a22cacdcff0e3a951e569210219b458168eba1e34f03e24f3
# Successfully built converter
# Installing collected packages: converter, chess, pgn2data
# Successfully installed chess-1.10.0 converter-1.0.0 pgn2data-0.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from converter.pgn_data import PGNData
from concurrent.futures import ThreadPoolExecutor, as_completed
import os

# function to process pgn to csv with games info and moves csv files
def process_pgn_file(pgn_file_path):

    try:
        pgn_data = PGNData(pgn_file_path)
        result = pgn_data.export()
        result.print_summary()  # Print summary of the export
        return f"Processing {pgn_file_path} completed successfully."
    except Exception as e:
        return f"Error processing {pgn_file_path}: {e}"

# Process a list of PGN files in parallel
def process_pgn_files_in_parallel(files):

    with ThreadPoolExecutor(max_workers=15) as executor:
        futures = {executor.submit(process_pgn_file, file): file for file in files}
        for future in as_completed(futures):
            print(future.result())

# Path to the directory containing the PGN files
pgn_directory = "/kaggle/working/pgn_2019_data"

# Get all PGN files in the directory
pgn_files = [os.path.join(pgn_directory, f) for f in os.listdir(pgn_directory) if f.endswith('.pgn')]

# Process in batches of 12
batch_size = 12
for i in range(0, len(pgn_files), batch_size):
    batch_files = pgn_files[i:i+batch_size]
    process_pgn_files_in_parallel(batch_files)
# Out:
# is complete: True
# games file: games_2019_part_37_game_info.csv | size: 956960
# moves file: games_2019_part_37_moves.csv | size: 167689452
# Processing /kaggle/working/pgn_2019_data/games_2019_part_37.pgn completed successfully.
# is complete: True
# games file: games_2019_part_15_game_info.csv | size: 2497093
# moves file: games_2019_part_15_moves.csv | size: 349895714
# Processing /kaggle/working/pgn_2019_data/games_2019_part_15.pgn completed successfully.
# is complete: True
# games file: games_2019_part_27_game_info.csv | size: 2536349
# moves file: games_2019_part_27_moves.csv | size: 351660057
# Processing /kaggle/working/pgn_2019_data/games_2019_part_27.pgn completed successfully.
# is complete: True
# games file: games_2019_part_29_game_info.csv | size: 2457295
# moves file: games_2019_part_29_moves.csv | size: 351107047
# Processing /kaggle/working/pgn_2019_data/games_2019_part_29.pgn completed successfully.
# is complete: True
# games file: games_2019_part_7_game_info.csv | size: 2501872
# moves file: games_2019_part_7_moves.csv | size: 355280961
# Processing /kaggle/working/pgn_2019_data/games_2019_part_7.pgn completed successfully.
# is complete: True
# games file: games_2019_part_35_game_info.csv | size: 2493687
# moves file: games_2019_part_35_moves.csv | size: 356715824
# Processing /kaggle/working/pgn_2019_data/games_2019_part_35.pgn completed successfully.
# is complete: True
# games file: games_2019_part_20_game_info.csv | size: 2488602
# moves file: games_2019_part_20_moves.csv | size: 355200853
# Processing /kaggle/working/pgn_2019_data/games_2019_part_20.pgn completed successfully.
# is complete: True
# games file: games_2019_part_8_game_info.csv | size: 2509743
# moves file: games_2019_part_8_moves.csv | size: 362647846
# Processing /kaggle/working/pgn_2019_data/games_2019_part_8.pgn completed successfully.
# is complete: True
# games file: games_2019_part_31_game_info.csv | size: 2452251
# moves file: games_2019_part_31_moves.csv | size: 366580503
# Processing /kaggle/working/pgn_2019_data/games_2019_part_31.pgn completed successfully.
# is complete: True
# games file: games_2019_part_19_game_info.csv | size: 2492503
# moves file: games_2019_part_19_moves.csv | size: 363393560
# Processing /kaggle/working/pgn_2019_data/games_2019_part_19.pgn completed successfully.
# is complete: True
# games file: games_2019_part_25_game_info.csv | size: 2471174
# moves file: games_2019_part_25_moves.csv | size: 365105458
# Processing /kaggle/working/pgn_2019_data/games_2019_part_25.pgn completed successfully.
# is complete: True
# games file: games_2019_part_5_game_info.csv | size: 2536201
# moves file: games_2019_part_5_moves.csv | size: 365716772
# Processing /kaggle/working/pgn_2019_data/games_2019_part_5.pgn completed successfully.
# is complete: True
# games file: games_2019_part_36_game_info.csv | size: 2418407
# moves file: games_2019_part_36_moves.csv | size: 331469655
# Processing /kaggle/working/pgn_2019_data/games_2019_part_36.pgn completed successfully.
# is complete: True
# games file: games_2019_part_17_game_info.csv | size: 2476416
# moves file: games_2019_part_17_moves.csv | size: 328486027
# Processing /kaggle/working/pgn_2019_data/games_2019_part_17.pgn completed successfully.
# is complete: True
# games file: games_2019_part_3_game_info.csv | size: 2415679
# moves file: games_2019_part_3_moves.csv | size: 345325631
# Processing /kaggle/working/pgn_2019_data/games_2019_part_3.pgn completed successfully.
# is complete: True
# games file: games_2019_part_24_game_info.csv | size: 2529583
# moves file: games_2019_part_24_moves.csv | size: 355107708
# Processing /kaggle/working/pgn_2019_data/games_2019_part_24.pgn completed successfully.
# is complete: True
# games file: games_2019_part_34_game_info.csv | size: 2559550
# moves file: games_2019_part_34_moves.csv | size: 354438708
# Processing /kaggle/working/pgn_2019_data/games_2019_part_34.pgn completed successfully.
# is complete: True
# games file: games_2019_part_32_game_info.csv | size: 2505754
# moves file: games_2019_part_32_moves.csv | size: 353029421
# Processing /kaggle/working/pgn_2019_data/games_2019_part_32.pgn completed successfully.
# is complete: True
# games file: games_2019_part_33_game_info.csv | size: 2494004
# moves file: games_2019_part_33_moves.csv | size: 351796351
# Processing /kaggle/working/pgn_2019_data/games_2019_part_33.pgn completed successfully.
# is complete: True
# games file: games_2019_part_9_game_info.csv | size: 2469066
# moves file: games_2019_part_9_moves.csv | size: 350210585
# Processing /kaggle/working/pgn_2019_data/games_2019_part_9.pgn completed successfully.
# is complete: True
# games file: games_2019_part_11_game_info.csv | size: 2474542
# moves file: games_2019_part_11_moves.csv | size: 355484944
# Processing /kaggle/working/pgn_2019_data/games_2019_part_11.pgn completed successfully.
# is complete: True
# games file: games_2019_part_23_game_info.csv | size: 2450780
# moves file: games_2019_part_23_moves.csv | size: 361434950
# Processing /kaggle/working/pgn_2019_data/games_2019_part_23.pgn completed successfully.
# is complete: True
# games file: games_2019_part_16_game_info.csv | size: 2471074
# moves file: games_2019_part_16_moves.csv | size: 359889662
# Processing /kaggle/working/pgn_2019_data/games_2019_part_16.pgn completed successfully.
# is complete: True
# games file: games_2019_part_4_game_info.csv | size: 2468181
# moves file: games_2019_part_4_moves.csv | size: 375155398
# Processing /kaggle/working/pgn_2019_data/games_2019_part_4.pgn completed successfully.
# is complete: True
# games file: games_2019_part_1_game_info.csv | size: 2429363
# moves file: games_2019_part_1_moves.csv | size: 318798004
# Processing /kaggle/working/pgn_2019_data/games_2019_part_1.pgn completed successfully.
# is complete: True
# games file: games_2019_part_2_game_info.csv | size: 2389863
# moves file: games_2019_part_2_moves.csv | size: 328086960
# Processing /kaggle/working/pgn_2019_data/games_2019_part_2.pgn completed successfully.
# is complete: True
# games file: games_2019_part_22_game_info.csv | size: 2389918
# moves file: games_2019_part_22_moves.csv | size: 324478543
# Processing /kaggle/working/pgn_2019_data/games_2019_part_22.pgn completed successfully.
# is complete: True
# games file: games_2019_part_12_game_info.csv | size: 2491437
# moves file: games_2019_part_12_moves.csv | size: 339098511
# Processing /kaggle/working/pgn_2019_data/games_2019_part_12.pgn completed successfully.
# is complete: True
# games file: games_2019_part_26_game_info.csv | size: 2523928
# moves file: games_2019_part_26_moves.csv | size: 347745991
# Processing /kaggle/working/pgn_2019_data/games_2019_part_26.pgn completed successfully.
# is complete: True
# games file: games_2019_part_13_game_info.csv | size: 2487168
# moves file: games_2019_part_13_moves.csv | size: 347422755
# Processing /kaggle/working/pgn_2019_data/games_2019_part_13.pgn completed successfully.
# is complete: True
# games file: games_2019_part_30_game_info.csv | size: 2488114
# moves file: games_2019_part_30_moves.csv | size: 351914516
# Processing /kaggle/working/pgn_2019_data/games_2019_part_30.pgn completed successfully.
# is complete: True
# games file: games_2019_part_28_game_info.csv | size: 2484795
# moves file: games_2019_part_28_moves.csv | size: 357599685
# Processing /kaggle/working/pgn_2019_data/games_2019_part_28.pgn completed successfully.
# is complete: True
# games file: games_2019_part_6_game_info.csv | size: 2512095
# moves file: games_2019_part_6_moves.csv | size: 359879229
# Processing /kaggle/working/pgn_2019_data/games_2019_part_6.pgn completed successfully.
# is complete: True
# games file: games_2019_part_10_game_info.csv | size: 2566531
# moves file: games_2019_part_10_moves.csv | size: 362713322
# Processing /kaggle/working/pgn_2019_data/games_2019_part_10.pgn completed successfully.
# is complete: True
# games file: games_2019_part_18_game_info.csv | size: 2478084
# moves file: games_2019_part_18_moves.csv | size: 373230598
# Processing /kaggle/working/pgn_2019_data/games_2019_part_18.pgn completed successfully.
# is complete: True
# games file: games_2019_part_14_game_info.csv | size: 2502821
# moves file: games_2019_part_14_moves.csv | size: 375454158
# Processing /kaggle/working/pgn_2019_data/games_2019_part_14.pgn completed successfully.
# is complete: True
# games file: games_2019_part_21_game_info.csv | size: 2519281
# moves file: games_2019_part_21_moves.csv | size: 345686661
# Processing /kaggle/working/pgn_2019_data/games_2019_part_21.pgn completed successfully.
