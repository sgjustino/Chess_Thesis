# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/thesis-chess-dataset/fourthSorted.pgn

# %%
import os

# Splits the PGN file into parts, each containing up to 'split_size' games from a specific year, and saves them to the output folder
def split_and_filter_games_by_year(pgn_file_path, year, split_size, output_folder):
    
    os.makedirs(output_folder, exist_ok=True)
    
    current_file_number = 1
    game_count = 0
    current_file_path = os.path.join(output_folder, f"games_2018_part_{current_file_number}.pgn")
    current_file = open(current_file_path, "w")
    
    with open(pgn_file_path, "r") as pgn:
        game_lines = []  # Hold the lines of a game
        for line in pgn:
            if line.startswith('[Event '):
                # Process the previous game
                if game_lines:
                    date_line = next((l for l in game_lines if l.startswith('[Date ')), '')
                    game_year = date_line.split('"')[1].split('.')[0]  # Extract the year part
                    if game_year == year:
                        game_count += 1
                        if game_count > split_size:
                            # Close current file and open a new one
                            current_file.close()
                            current_file_number += 1
                            current_file_path = os.path.join(output_folder, f"games_2018_part_{current_file_number}.pgn")
                            current_file = open(current_file_path, "w")
                            game_count = 1  # Reset the count for the new file
                        current_file.writelines(game_lines)
                game_lines = [line]  # Start a new game
            else:
                game_lines.append(line)
        
        # Check for the last game in the file
        if game_lines:
            date_line = next((l for l in game_lines if l.startswith('[Date ')), '')
            game_year = date_line.split('"')[1].split('.')[0]
            if game_year == year:
                current_file.writelines(game_lines)
                
    current_file.close()  # Ensure the last file is closed after the loop finishes

# Path to the directory containing the PGN file
pgn_file_path = "/kaggle/input/thesis-chess-dataset/fourthSorted.pgn"
# Selection of filter for year
year = "2018"
# File size for split by no. of games
split_size = 10000

output_folder = "pgn_2018_data"

# Call the function
split_and_filter_games_by_year(pgn_file_path, year, split_size, output_folder)

# %%
pip install converter pgn2data
# Out:
# Collecting converter
#   Downloading converter-1.0.0.zip (1.3 kB)
# done
# Collecting pgn2data
#   Downloading pgn2data-0.0.9-py3-none-any.whl.metadata (9.8 kB)
# Collecting chess (from pgn2data)
#   Downloading chess-1.10.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from pgn2data) (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->pgn2data) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->pgn2data) (1.16.0)
# Downloading pgn2data-0.0.9-py3-none-any.whl (31 kB)
# Downloading chess-1.10.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 8.8 MB/s eta 0:00:00
# Building wheels for collected packages: converter
# done
#   Created wheel for converter: filename=converter-1.0.0-py3-none-any.whl size=1751 sha256=a0c71102fd7b99db99912f8fc29936dfc2cfd8d0d0debfbaffb6e6579a111ca9
#   Stored in directory: /root/.cache/pip/wheels/fd/74/44/8a22cacdcff0e3a951e569210219b458168eba1e34f03e24f3
# Successfully built converter
# Installing collected packages: converter, chess, pgn2data
# Successfully installed chess-1.10.0 converter-1.0.0 pgn2data-0.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
from converter.pgn_data import PGNData
from concurrent.futures import ThreadPoolExecutor, as_completed
import os

# function to process pgn to csv with games info and moves csv files
def process_pgn_file(pgn_file_path):

    try:
        pgn_data = PGNData(pgn_file_path)
        result = pgn_data.export()
        result.print_summary()  # Print summary of the export
        return f"Processing {pgn_file_path} completed successfully."
    except Exception as e:
        return f"Error processing {pgn_file_path}: {e}"

# Process a list of PGN files in parallel
def process_pgn_files_in_parallel(files):

    with ThreadPoolExecutor(max_workers=15) as executor:
        futures = {executor.submit(process_pgn_file, file): file for file in files}
        for future in as_completed(futures):
            print(future.result())

# Path to the directory containing the PGN files
pgn_directory = "/kaggle/working/pgn_2018_data"

# Get all PGN files in the directory
pgn_files = [os.path.join(pgn_directory, f) for f in os.listdir(pgn_directory) if f.endswith('.pgn')]

# Process in batches of 12
batch_size = 12
for i in range(0, len(pgn_files), batch_size):
    batch_files = pgn_files[i:i+batch_size]
    process_pgn_files_in_parallel(batch_files)
# Out:
# is complete: True
# games file: games_2018_part_38_game_info.csv | size: 886970
# moves file: games_2018_part_38_moves.csv | size: 157478944
# Processing /kaggle/working/pgn_2018_data/games_2018_part_38.pgn completed successfully.
# is complete: True
# games file: games_2018_part_1_game_info.csv | size: 2432858
# moves file: games_2018_part_1_moves.csv | size: 314438828
# Processing /kaggle/working/pgn_2018_data/games_2018_part_1.pgn completed successfully.
# is complete: True
# games file: games_2018_part_27_game_info.csv | size: 2456418
# moves file: games_2018_part_27_moves.csv | size: 331591107
# Processing /kaggle/working/pgn_2018_data/games_2018_part_27.pgn completed successfully.
# is complete: True
# games file: games_2018_part_2_game_info.csv | size: 2385938
# moves file: games_2018_part_2_moves.csv | size: 334027917
# Processing /kaggle/working/pgn_2018_data/games_2018_part_2.pgn completed successfully.
# is complete: True
# games file: games_2018_part_34_game_info.csv | size: 2445933
# moves file: games_2018_part_34_moves.csv | size: 345519553
# Processing /kaggle/working/pgn_2018_data/games_2018_part_34.pgn completed successfully.
# is complete: True
# games file: games_2018_part_33_game_info.csv | size: 2498801
# moves file: games_2018_part_33_moves.csv | size: 356602306
# Processing /kaggle/working/pgn_2018_data/games_2018_part_33.pgn completed successfully.
# is complete: True
# games file: games_2018_part_16_game_info.csv | size: 2499618
# moves file: games_2018_part_16_moves.csv | size: 360479336
# Processing /kaggle/working/pgn_2018_data/games_2018_part_16.pgn completed successfully.
# is complete: True
# games file: games_2018_part_11_game_info.csv | size: 2506108
# moves file: games_2018_part_11_moves.csv | size: 363839118
# Processing /kaggle/working/pgn_2018_data/games_2018_part_11.pgn completed successfully.
# is complete: True
# games file: games_2018_part_37_game_info.csv | size: 2435300
# moves file: games_2018_part_37_moves.csv | size: 366809125
# Processing /kaggle/working/pgn_2018_data/games_2018_part_37.pgn completed successfully.
# is complete: True
# games file: games_2018_part_20_game_info.csv | size: 2463636
# moves file: games_2018_part_20_moves.csv | size: 360679596
# Processing /kaggle/working/pgn_2018_data/games_2018_part_20.pgn completed successfully.
# is complete: True
# games file: games_2018_part_5_game_info.csv | size: 2537331
# moves file: games_2018_part_5_moves.csv | size: 377479480
# Processing /kaggle/working/pgn_2018_data/games_2018_part_5.pgn completed successfully.
# is complete: True
# games file: games_2018_part_28_game_info.csv | size: 2470193
# moves file: games_2018_part_28_moves.csv | size: 380168217
# Processing /kaggle/working/pgn_2018_data/games_2018_part_28.pgn completed successfully.
# is complete: True
# games file: games_2018_part_15_game_info.csv | size: 2505196
# moves file: games_2018_part_15_moves.csv | size: 329494471
# Processing /kaggle/working/pgn_2018_data/games_2018_part_15.pgn completed successfully.
# is complete: True
# games file: games_2018_part_36_game_info.csv | size: 2464361
# moves file: games_2018_part_36_moves.csv | size: 341142402
# Processing /kaggle/working/pgn_2018_data/games_2018_part_36.pgn completed successfully.
# is complete: True
# games file: games_2018_part_9_game_info.csv | size: 2476906
# moves file: games_2018_part_9_moves.csv | size: 333654767
# Processing /kaggle/working/pgn_2018_data/games_2018_part_9.pgn completed successfully.
# is complete: True
# games file: games_2018_part_10_game_info.csv | size: 2510757
# moves file: games_2018_part_10_moves.csv | size: 350920977
# Processing /kaggle/working/pgn_2018_data/games_2018_part_10.pgn completed successfully.
# is complete: True
# games file: games_2018_part_8_game_info.csv | size: 2500016
# moves file: games_2018_part_8_moves.csv | size: 342950380
# Processing /kaggle/working/pgn_2018_data/games_2018_part_8.pgn completed successfully.
# is complete: True
# games file: games_2018_part_23_game_info.csv | size: 2468577
# moves file: games_2018_part_23_moves.csv | size: 356562701
# Processing /kaggle/working/pgn_2018_data/games_2018_part_23.pgn completed successfully.
# is complete: True
# games file: games_2018_part_32_game_info.csv | size: 2469969
# moves file: games_2018_part_32_moves.csv | size: 347865595
# Processing /kaggle/working/pgn_2018_data/games_2018_part_32.pgn completed successfully.
# is complete: True
# games file: games_2018_part_26_game_info.csv | size: 2493294
# moves file: games_2018_part_26_moves.csv | size: 356744563
# Processing /kaggle/working/pgn_2018_data/games_2018_part_26.pgn completed successfully.
# is complete: True
# games file: games_2018_part_30_game_info.csv | size: 2457055
# moves file: games_2018_part_30_moves.csv | size: 353922557
# Processing /kaggle/working/pgn_2018_data/games_2018_part_30.pgn completed successfully.
# is complete: True
# games file: games_2018_part_6_game_info.csv | size: 2470947
# moves file: games_2018_part_6_moves.csv | size: 364273080
# Processing /kaggle/working/pgn_2018_data/games_2018_part_6.pgn completed successfully.
# is complete: True
# games file: games_2018_part_4_game_info.csv | size: 2479059
# moves file: games_2018_part_4_moves.csv | size: 357715300
# Processing /kaggle/working/pgn_2018_data/games_2018_part_4.pgn completed successfully.
# is complete: True
# games file: games_2018_part_17_game_info.csv | size: 2460352
# moves file: games_2018_part_17_moves.csv | size: 360920909
# Processing /kaggle/working/pgn_2018_data/games_2018_part_17.pgn completed successfully.
# is complete: True
# games file: games_2018_part_3_game_info.csv | size: 2427347
# moves file: games_2018_part_3_moves.csv | size: 335346955
# Processing /kaggle/working/pgn_2018_data/games_2018_part_3.pgn completed successfully.
# is complete: True
# games file: games_2018_part_18_game_info.csv | size: 2473837
# moves file: games_2018_part_18_moves.csv | size: 348152496
# Processing /kaggle/working/pgn_2018_data/games_2018_part_18.pgn completed successfully.
# is complete: True
# games file: games_2018_part_7_game_info.csv | size: 2510376
# moves file: games_2018_part_7_moves.csv | size: 339800697
# Processing /kaggle/working/pgn_2018_data/games_2018_part_7.pgn completed successfully.
# is complete: True
# games file: games_2018_part_29_game_info.csv | size: 2509356
# moves file: games_2018_part_29_moves.csv | size: 338252531
# Processing /kaggle/working/pgn_2018_data/games_2018_part_29.pgn completed successfully.
# is complete: True
# games file: games_2018_part_22_game_info.csv | size: 2438136
# moves file: games_2018_part_22_moves.csv | size: 346951990
# Processing /kaggle/working/pgn_2018_data/games_2018_part_22.pgn completed successfully.
# is complete: True
# games file: games_2018_part_12_game_info.csv | size: 2569072
# moves file: games_2018_part_12_moves.csv | size: 354284585
# Processing /kaggle/working/pgn_2018_data/games_2018_part_12.pgn completed successfully.
# is complete: True
# games file: games_2018_part_21_game_info.csv | size: 2458075
# moves file: games_2018_part_21_moves.csv | size: 353597851
# Processing /kaggle/working/pgn_2018_data/games_2018_part_21.pgn completed successfully.
# is complete: True
# games file: games_2018_part_13_game_info.csv | size: 2453941
# moves file: games_2018_part_13_moves.csv | size: 355179990
# Processing /kaggle/working/pgn_2018_data/games_2018_part_13.pgn completed successfully.
# is complete: True
# games file: games_2018_part_31_game_info.csv | size: 2445421
# moves file: games_2018_part_31_moves.csv | size: 358008811
# Processing /kaggle/working/pgn_2018_data/games_2018_part_31.pgn completed successfully.
# is complete: True
# games file: games_2018_part_19_game_info.csv | size: 2432434
# moves file: games_2018_part_19_moves.csv | size: 355427432
# Processing /kaggle/working/pgn_2018_data/games_2018_part_19.pgn completed successfully.
# is complete: True
# games file: games_2018_part_35_game_info.csv | size: 2523899
# moves file: games_2018_part_35_moves.csv | size: 355328944
# Processing /kaggle/working/pgn_2018_data/games_2018_part_35.pgn completed successfully.
# is complete: True
# games file: games_2018_part_24_game_info.csv | size: 2542440
# moves file: games_2018_part_24_moves.csv | size: 359873049
# Processing /kaggle/working/pgn_2018_data/games_2018_part_24.pgn completed successfully.
# is complete: True
# games file: games_2018_part_14_game_info.csv | size: 2484998
# moves file: games_2018_part_14_moves.csv | size: 346525911
# Processing /kaggle/working/pgn_2018_data/games_2018_part_14.pgn completed successfully.
# is complete: True
# games file: games_2018_part_25_game_info.csv | size: 2478211
# moves file: games_2018_part_25_moves.csv | size: 348997770
# Processing /kaggle/working/pgn_2018_data/games_2018_part_25.pgn completed successfully.
